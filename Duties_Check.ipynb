# %%
TIMETABLE_FILE = "C:/Users/srupe/Desktop/MTP/crew/mainLoop_aadesh.csv"

# %%
# === Utility Functions ===
def parse_time_to_minutes(t: str):
    """
    Converts a time string 'HH:MM' or 'HH:MM:SS' into minutes since midnight.
    Supports hours >= 24 (e.g., 24:05 → 1445 minutes, 25:07 → 1507 minutes)
    """
    try:
        t = t.strip()
        # Split HH:MM or HH:MM:SS
        parts = t.split(":")
        hours = int(parts[0])
        minutes = int(parts[1])
        return hours * 60 + minutes
    except:
        return None


def get_base_station_name(station: str):
    """Extracts the base station name (first word) in uppercase."""
    if not station:
        return None
    return station.strip().split()[0].upper()

# %%
class Service:
    def __init__(
        self,
        service_id, 
        rake_num,
        start_station,
        start_time,
        end_station,
        end_time,
        direction,
        service_time=0,
        same_jurisdiction=None,
        step_back_rake=None,
        step_back_location=None,
        merged_rake_num1=None,
        merged_rake_num2=None
    ):
        self.service_id = str(service_id)
        self.rake_num = rake_num
        self.start_station = start_station
        self.start_time = start_time
        self.end_station = end_station
        self.end_time = end_time
        self.direction = direction
        self.service_time = int(service_time) if service_time else 0
        self.same_jurisdiction = same_jurisdiction
        self.step_back_rake = step_back_rake
        self.step_back_location = step_back_location
        self.merged_rake_num1 = merged_rake_num1
        self.merged_rake_num2 = merged_rake_num2


def load_services(csv_file):
    df = pd.read_csv(csv_file)
    services = []
    for _, row in df.iterrows():
        s = Service(
            service_id=row.get("Service"),   
            rake_num=row.get("Rake Num"),
            start_station=get_base_station_name(row.get("Start Station")),
            start_time=parse_time_to_minutes(row.get("Start Time")),
            end_station=get_base_station_name(row.get("End Station")),
            end_time=parse_time_to_minutes(row.get("End Time")),
            direction=row.get("Direction"),
            service_time=int(row["service time"]) if "service time" in row and pd.notna(row["service time"]) else 0,
            same_jurisdiction=row["Same Jurisdiction"] if "Same Jurisdiction" in row else None,
            step_back_rake=row["Step Back Rake"] if "Step Back Rake" in row else None,
            step_back_location=row["Step Back Location"] if "Step Back Location" in row else None,
            merged_rake_num1=row["mergedRakeNum1"] if "mergedRakeNum1" in row else None,
            merged_rake_num2=row["mergedRakeNum2"] if "mergedRakeNum2" in row else None,
        )
        services.append(s)
    return services

# %%
# === Configuration ===
#TIMETABLE_FILE = "C:/Users/srupe/Downloads/crew/mainLoop_aadesh.csv"
MIN_RAKE_GAP_MINUTES = 30   # Minimum required gap between different rakes
ALLOWED_RAKE_CHANGE_STATIONS = {"KKDA", "PVGW"}  # Allowed rake-change stations
MAX_CONNECTION_GAP_MINUTES = 120   # Maximum allowed gap between services

BREAK_STATIONS = {"KKDA", "PVGW"}  # Breaks allowed only here
CUMULATIVE_BREAKS_DURATION = 120    # cumulative breaks should be less than CUMULATIVE_BREAKS_DURATIONS min
SHORT_BREAK = 30     # short break duration
LONG_BREAK =  50     # Long break duration
DUTY_TIME_LIMIT = 445 # Noraml duty duration
MORN_EVEN_DUTY_TIME_LIMIT = 405  # morning and evening duty time duration
MORNING_SHIFT_CUTOFF = 360     # 360 -> 6:00 AM
EVENING_SHIFT_CUTOFF = 1410     # 1410 -> 23:30 PM
CONTINUOUS_DRIVE_LIMIT = 180   # continuous driving without a break greater than 30 mins in it.
DRIVING_TIME_LIMIT =360        # Actual driving time(Mins) it have gaps< SHORT_BREAKS also counted in it


# === Jurisdiction Buckets ===
jurisdiction_dict = {
    1: {'MKPR','MKPR UP','MKPR DN','SAKP','DDSC','DDSC DN PF','DDSC SDG','DDSC SDG STABLE (DAY)','DDSC DN',
        'DDSC SDG','PVGW','PVGW UP','PVGW DN','MKPD','MKPD','SAKP 3RD','SAKP 3RD PF','MKPR DN SDG','MKPR DN PF','DDSC DN SDG'},
    2: {'MUPR DN SDG STABLE (DAY)','MUPR 4TH SDG STABLE (DAY)','MUPR 3RD SDG STABLE','SVVR','SVVR DN','MUPR',
        'MUPR DN','MUPR 4TH','MUPR 3RD SDG','KKDA DN','KKDA UP','IPE','IPE 3RD PF','IPE 3RD','VND','VND (M)',
        'MVPO','MVPO DN','NZM','NIZM','KKDA','MUPR DN SDG','MVPO DN PF','SVVR DN PF','MUPR 3RD SDG','MUPR 4TH PF',
        'MUPR 4TH SDG','MUPR DN PF','MUPR DN SDG','MUPR DN SDG'}
}

# %%
import pandas as pd
from tabulate import tabulate

# ---------------- PARAMETERS ----------------
MIN_RAKE_GAP_MINUTES = 30
ALLOWED_RAKE_CHANGE_STATIONS = {"KKDA", "PVGW"}
MAX_CONNECTION_GAP_MINUTES = 120

BREAK_STATIONS = {"KKDA", "PVGW"}
CUMULATIVE_BREAKS_DURATION = 120
SHORT_BREAK = 30
LONG_BREAK = 50
DUTY_TIME_LIMIT = 445
MORN_EVEN_DUTY_TIME_LIMIT = 405
MORNING_SHIFT_CUTOFF = 360
EVENING_SHIFT_CUTOFF = 1410
CONTINUOUS_DRIVE_LIMIT = 180
DRIVING_TIME_LIMIT = 360

jurisdiction_dict = {
    1: {'MKPR','MKPR UP','MKPR DN','SAKP','DDSC','DDSC DN PF','DDSC SDG','DDSC SDG STABLE (DAY)','DDSC DN',
        'DDSC SDG','PVGW','PVGW UP','PVGW DN','MKPD','MKPD','SAKP 3RD','SAKP 3RD PF','MKPR DN SDG','MKPR DN PF','DDSC DN SDG'},
    2: {'MUPR DN SDG STABLE (DAY)','MUPR 4TH SDG STABLE (DAY)','MUPR 3RD SDG STABLE','SVVR','SVVR DN','MUPR',
        'MUPR DN','MUPR 4TH','MUPR 3RD SDG','KKDA DN','KKDA UP','IPE','IPE 3RD PF','IPE 3RD','VND','VND (M)',
        'MVPO','MVPO DN','NZM','NIZM','KKDA','MUPR DN SDG','MVPO DN PF','SVVR DN PF','MUPR 3RD SDG','MUPR 4TH PF',
        'MUPR 4TH SDG','MUPR DN PF','MUPR DN SDG','MUPR DN SDG'}
}


# ---------------- HELPER FUNCTIONS ----------------
def minutes_to_hhmm(minutes):
    """Convert minutes since midnight → HH:MM format"""
    h = minutes // 60
    m = minutes % 60
    return f"{h:02d}:{m:02d}"


def get_jurisdiction(station):
    """Find jurisdiction ID for a station name"""
    for j_id, stations in jurisdiction_dict.items():
        if station in stations:
            return j_id
    return None


# ---------------- ANALYSIS FUNCTION ----------------
def analyze_duty(service_ids, all_services):
    service_dict = {s.service_id: s for s in all_services}
    duty_services = [service_dict[str(sid)] for sid in service_ids if str(sid) in service_dict]
    duty_services.sort(key=lambda s: s.start_time)

    rows = []
    total_driving_time = 0
    cumulative_breaks = 0
    rake_changes = []
    continuous_drive = 0
    max_continuous_drive = 0

    # --- Jurisdiction check ---
    first_jurisdiction = get_jurisdiction(duty_services[0].start_station)
    last_jurisdiction = get_jurisdiction(duty_services[-1].end_station)
    same_jurisdiction = first_jurisdiction == last_jurisdiction

    # --- Iterate through services ---
    for i, s in enumerate(duty_services):
        break_after = "-"
        rake_change = "-"
        gap = "-"
        
        if i < len(duty_services) - 1:
            next_s = duty_services[i + 1]
            gap = next_s.start_time - s.end_time
            
            if gap >= SHORT_BREAK:
                # OK Break detected
                break_after = f"{gap} mins OK"
                cumulative_breaks += gap
                max_continuous_drive = max(max_continuous_drive, continuous_drive)
                continuous_drive = 0
            else:
                # gap < 30 → count as continuous driving
                continuous_drive += s.service_time + gap
                total_driving_time += gap
            
            #  Check rake change
            if s.rake_num != next_s.rake_num:
                if s.end_station in ALLOWED_RAKE_CHANGE_STATIONS:
                    rake_change = f"Rake changed at {s.end_station} after {s.service_id}"
                    rake_changes.append((s.service_id, s.end_station))
                else:
                    rake_change = f" Invalid rake change at {s.end_station}"
        else:
            continuous_drive += s.service_time
        
        total_driving_time += s.service_time

        rows.append([
            s.service_id,
            minutes_to_hhmm(s.start_time),   # Start before From
            minutes_to_hhmm(s.end_time),     # End before To
            s.start_station,
            s.end_station,
            s.service_time,
            gap if gap != "-" else "-",
            break_after,
            rake_change
        ])
    
    # Update max continuous drive for last streak
    max_continuous_drive = max(max_continuous_drive, continuous_drive)

    # --- Duty & Summary ---
    duty_start = duty_services[0].start_time
    duty_end = duty_services[-1].end_time
    duty_duration = duty_end - duty_start

    summary = [
        ["Total Driving Time", f"{total_driving_time} <= {DRIVING_TIME_LIMIT}", "OK" if total_driving_time <= DRIVING_TIME_LIMIT else "Error"],
        ["Cumulative Breaks", f"{cumulative_breaks} <= {CUMULATIVE_BREAKS_DURATION}", "OK" if cumulative_breaks <= CUMULATIVE_BREAKS_DURATION else "Error"],
        ["Duty Duration", f"{duty_duration} <= {DUTY_TIME_LIMIT}", "OK" if duty_duration <= DUTY_TIME_LIMIT else "Error"],
        ["Max Continuous Drive", f"{max_continuous_drive} <= {CONTINUOUS_DRIVE_LIMIT}", "OK" if max_continuous_drive <= CONTINUOUS_DRIVE_LIMIT else "Error"],
        ["Jurisdiction Match", f"{first_jurisdiction} == {last_jurisdiction}", "OK" if same_jurisdiction else "Error"],
        ["Rake Changes", str(len(rake_changes)), ", ".join([f"{r[1]} after {r[0]}" for r in rake_changes]) or "-"]
    ]

    # --- Print Results ---
    print("\n---  Duty Timeline ---")
    print(tabulate(
        rows,
        headers=["Service_ID", "Start", "End", "From", "To", "Service Time", "Gap (mins)", "Break", "Rake Change"],
        tablefmt="pretty"
    ))

    print("\n---  Constraint Summary ---")
    print(tabulate(summary, headers=["Constraint", "Condition", "Status"], tablefmt="pretty"))


# ---------------- USAGE EXAMPLE ----------------
services = load_services(TIMETABLE_FILE)
duty_ids = [18,583,586,28,70,119,442,159]
analyze_duty(duty_ids, services)
# Out:
# ---  Duty Timeline ---
# +------------+-------+-------+------+------+--------------+------------+------------+-------------------------------+
# | Service_ID | Start |  End  | From |  To  | Service Time | Gap (mins) |   Break    |          Rake Change          |
# +------------+-------+-------+------+------+--------------+------------+------------+-------------------------------+
# |     18     | 06:15 | 06:21 | VND  | KKDA |      6       |     0      |     -      |               -               |
# |    583     | 06:21 | 06:36 | KKDA | MUPR |      15      |     4      |     -      |               -               |
# |    586     | 06:40 | 06:55 | MUPR | KKDA |      15      |     0      |     -      |               -               |
# |     28     | 06:55 | 08:01 | KKDA | PVGW |      66      |     45     | 45 mins OK | Rake changed at PVGW after 28 |
# |     70     | 08:46 | 09:52 | PVGW | KKDA |      66      |     51     | 51 mins OK | Rake changed at KKDA after 70 |
# |    119     | 10:43 | 11:50 | KKDA | PVGW |      67      |     0      |     -      |               -               |
# |    442     | 11:50 | 12:25 | PVGW | PVGW |      35      |     0      |     -      |               -               |
# |    159     | 12:25 | 13:31 | PVGW | KKDA |      66      |     -      |     -      |               -               |
# +------------+-------+-------+------+------+--------------+------------+------------+-------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+------------------------------+
# |      Constraint      | Condition  |            Status            |
# +----------------------+------------+------------------------------+
# |  Total Driving Time  | 340 <= 360 |              OK              |
# |  Cumulative Breaks   | 96 <= 120  |              OK              |
# |    Duty Duration     | 436 <= 445 |              OK              |
# | Max Continuous Drive | 168 <= 180 |              OK              |
# |  Jurisdiction Match  |   2 == 2   |              OK              |
# |     Rake Changes     |     2      | PVGW after 28, KKDA after 70 |
# +----------------------+------------+------------------------------+

# %%
import pandas as pd
from tabulate import tabulate

# ------------------ HELPER FUNCTIONS ------------------
def minutes_to_hhmm(minutes):
    h = minutes // 60
    m = minutes % 60
    return f"{h:02d}:{m:02d}"

def get_jurisdiction(station):
    for j_id, stations in jurisdiction_dict.items():
        if station in stations:
            return j_id
    return None

# ------------------ MAIN ANALYSIS ------------------
def analyze_duty(service_ids, all_services):
    service_dict = {s.service_id: s for s in all_services}
    duty_services = [service_dict[str(sid)] for sid in service_ids if str(sid) in service_dict]
    duty_services.sort(key=lambda s: s.start_time)

    rows = []
    total_driving_time = 0
    cumulative_breaks = 0
    rake_changes = []
    continuous_drive = 0
    max_continuous_drive = 0

    # Jurisdiction check
    first_jurisdiction = get_jurisdiction(duty_services[0].start_station)
    last_jurisdiction = get_jurisdiction(duty_services[-1].end_station)
    same_jurisdiction = first_jurisdiction == last_jurisdiction

    for i, s in enumerate(duty_services):
        break_after = "-"
        rake_change = "-"
        gap = "-"
        
        if i < len(duty_services) - 1:
            next_s = duty_services[i + 1]
            gap = next_s.start_time - s.end_time
            
            if gap >= SHORT_BREAK:
                break_after = f"{gap} mins OK"
                cumulative_breaks += gap
                max_continuous_drive = max(max_continuous_drive, continuous_drive)
                continuous_drive = 0
            else:
                continuous_drive += s.service_time + gap
                total_driving_time += gap
            
            if s.rake_num != next_s.rake_num:
                if s.end_station in ALLOWED_RAKE_CHANGE_STATIONS:
                    rake_change = f"Rake changed at {s.end_station} after {s.service_id}"
                    rake_changes.append((s.service_id, s.end_station))
                else:
                    rake_change = f" Invalid rake change at {s.end_station}"
        else:
            continuous_drive += s.service_time
        
        total_driving_time += s.service_time

        rows.append([
            s.service_id,
            minutes_to_hhmm(s.start_time),   # Start before From
            minutes_to_hhmm(s.end_time),     # End before To
            s.start_station,
            s.end_station,
            s.service_time,
            gap if gap != "-" else "-",
            break_after,
            rake_change
        ])
    
    
    max_continuous_drive = max(max_continuous_drive, continuous_drive)

    duty_start = duty_services[0].start_time
    duty_end = duty_services[-1].end_time
    duty_duration = duty_end - duty_start

    summary = [
        ["Total Driving Time", f"{total_driving_time} <= {DRIVING_TIME_LIMIT}", "OK" if total_driving_time <= DRIVING_TIME_LIMIT else "Error"],
        ["Cumulative Breaks", f"{cumulative_breaks} <= {CUMULATIVE_BREAKS_DURATION}", "OK" if cumulative_breaks <= CUMULATIVE_BREAKS_DURATION else "Error"],
        ["Duty Duration", f"{duty_duration} <= {DUTY_TIME_LIMIT}", "OK" if duty_duration <= DUTY_TIME_LIMIT else "Error"],
        ["Max Continuous Drive", f"{max_continuous_drive} <= {CONTINUOUS_DRIVE_LIMIT}", "OK" if max_continuous_drive <= CONTINUOUS_DRIVE_LIMIT else "Error"],
        ["Jurisdiction Match", f"{first_jurisdiction} == {last_jurisdiction}", "OK" if same_jurisdiction else "Error"],
        ["Rake Changes", str(len(rake_changes)), ", ".join([f"{r[1]} after {r[0]}" for r in rake_changes]) or "-"]
    ]

    print("\n---  Duty Timeline ---")
    print(tabulate(
        rows,
        headers=["Service", "From", "To", "Start", "End", "Service Time", "Gap (mins)", "Break", "Rake Change"],
        tablefmt="pretty"
    ))

    print("\n---  Constraint Summary ---")
    print(tabulate(summary, headers=["Constraint", "Condition", "Status"], tablefmt="pretty"))


# ------------------ RUN FOR EACH ROW IN CSV ------------------
def analyze_duty_csv(csv_file, all_services):
    with open(csv_file, "r") as f:
        lines = f.readlines()
    #df = pd.read_csv(csv_file, header=None)  # Each row is one duty
    for idx, line in enumerate(lines):
            line = line.strip()
            if not line:
                continue
            # Split by comma, convert to int
            service_ids = [int(sid.strip()) for sid in line.split(",") if sid.strip()]
            print(f"\n=================  Duty #{idx+1} =================")
            analyze_duty(service_ids, all_services)


TIMETABLE_FILE = "C:/Users/srupe/Desktop/MTP/crew/mainLoop_aadesh.csv"
services = load_services(TIMETABLE_FILE)
analyze_duty_csv("C:/Users/srupe/Desktop/MTP/crew/Solution/solution_2/solution_Network_11_10.csv", services)
# Out:
# =================  Duty #1 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   573   | SAKP | PVGW | 18:05 | 18:08 |      3       |     0      |     -      |               -                |
# |   275   | PVGW | KKDA | 18:08 | 19:14 |      66      |     0      |     -      |               -                |
# |   855   | KKDA | MUPR | 19:14 | 19:29 |      15      |     2      |     -      |               -                |
# |   862   | MUPR | KKDA | 19:31 | 19:47 |      16      |     0      |     -      |               -                |
# |   314   | KKDA | PVGW | 19:47 | 20:53 |      66      |     51     | 51 mins OK | Rake changed at PVGW after 314 |
# |   353   | PVGW | KKDA | 21:44 | 22:50 |      66      |     33     | 33 mins OK | Rake changed at KKDA after 353 |
# |   372   | KKDA | PVGW | 23:23 | 24:29 |      66      |     0      |     -      |               -                |
# |   564   | PVGW | MKPD | 24:29 | 24:44 |      15      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 315 <= 360 |               OK               |
# |  Cumulative Breaks   | 84 <= 120  |               OK               |
# |    Duty Duration     | 399 <= 445 |               OK               |
# | Max Continuous Drive | 102 <= 180 |               OK               |
# |  Jurisdiction Match  |   1 == 1   |               OK               |
# |     Rake Changes     |     2      | PVGW after 314, KKDA after 353 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #2 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   825   | KKDA | MUPR | 17:56 | 18:11 |      15      |     3      |     -      |               -                |
# |   832   | MUPR | KKDA | 18:14 | 18:29 |      15      |     60     | 60 mins OK | Rake changed at KKDA after 832 |
# |   861   | KKDA | MUPR | 19:29 | 19:44 |      15      |     3      |     -      |               -                |
# |   868   | MUPR | KKDA | 19:47 | 20:02 |      15      |     0      |     -      |               -                |
# |   320   | KKDA | PVGW | 20:02 | 21:09 |      67      |     0      |     -      |               -                |
# |   542   | PVGW | PVGW | 21:09 | 21:44 |      35      |     37     | 37 mins OK | Rake changed at PVGW after 542 |
# |   552   | PVGW | PVGW | 22:21 | 22:59 |      38      |     0      |     -      |               -                |
# |   368   | PVGW | KKDA | 22:59 | 24:05 |      66      |     0      |     -      |               -                |
# |   939   | KKDA | MUPR | 24:05 | 24:21 |      16      |     0      |     -      |               -                |
# |   569   | MUPR | MUPR | 24:21 | 24:40 |      19      |     0      |     -      |               -                |
# |   943   | MUPR | MUPR | 24:40 | 25:00 |      20      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 327 <= 360 |               OK               |
# |  Cumulative Breaks   | 97 <= 120  |               OK               |
# |    Duty Duration     | 424 <= 445 |               OK               |
# | Max Continuous Drive | 159 <= 180 |               OK               |
# |  Jurisdiction Match  |   2 == 2   |               OK               |
# |     Rake Changes     |     2      | KKDA after 832, PVGW after 542 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #3 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   270   | VND  | PVGW | 17:55 | 18:54 |      59      |     0      |     -      |               -                |
# |   518   | PVGW | PVGW | 18:54 | 19:30 |      36      |     68     | 68 mins OK | Rake changed at PVGW after 518 |
# |   537   | PVGW | PVGW | 20:38 | 21:14 |      36      |     0      |     -      |               -                |
# |   344   | PVGW | KKDA | 21:14 | 22:20 |      66      |     0      |     -      |               -                |
# |   920   | KKDA | MUPR | 22:20 | 22:36 |      16      |     0      |     -      |               -                |
# |   565   | MUPR | MUPR | 22:36 | 22:53 |      17      |     0      |     -      |               -                |
# |   926   | MUPR | KKDA | 22:53 | 23:08 |      15      |     42     | 42 mins OK | Rake changed at KKDA after 926 |
# |   937   | KKDA | MUPR | 23:50 | 24:06 |      16      |     0      |     -      |               -                |
# |   940   | MUPR | SVVR | 24:06 | 24:12 |      6       |     5      |     -      |               -                |
# |   376   | SVVR | IPE  | 24:17 | 25:07 |      50      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 322 <= 360 |               OK               |
# |  Cumulative Breaks   | 110 <= 120 |               OK               |
# |    Duty Duration     | 432 <= 445 |               OK               |
# | Max Continuous Drive | 135 <= 180 |               OK               |
# |  Jurisdiction Match  |   2 == 2   |               OK               |
# |     Rake Changes     |     2      | PVGW after 518, KKDA after 926 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #4 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   819   | KKDA | MUPR | 17:41 | 17:56 |      15      |     2      |     -      |               -                |
# |   826   | MUPR | KKDA | 17:58 | 18:14 |      16      |     0      |     -      |               -                |
# |   278   | KKDA | PVGW | 18:14 | 19:20 |      66      |     0      |     -      |               -                |
# |   523   | PVGW | PVGW | 19:20 | 19:56 |      36      |     47     | 47 mins OK | Rake changed at PVGW after 523 |
# |   538   | PVGW | PVGW | 20:43 | 21:24 |      41      |     0      |     -      |               -                |
# |   347   | PVGW | KKDA | 21:24 | 22:30 |      66      |     0      |     -      |               -                |
# |   922   | KKDA | MUPR | 22:30 | 22:46 |      16      |     0      |     -      |               -                |
# |   566   | MUPR | MUPR | 22:46 | 23:08 |      22      |     0      |     -      |               -                |
# |   929   | MUPR | KKDA | 23:08 | 23:23 |      15      |     57     | 57 mins OK | Rake changed at KKDA after 929 |
# |   941   | KKDA | MUPR | 24:20 | 24:36 |      16      |     0      |     -      |               -                |
# |   942   | MUPR | SVVR | 24:36 | 24:42 |      6       |     0      |     -      |               -                |
# |   576   | SVVR | SVVR | 24:42 | 25:02 |      20      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 337 <= 360 |               OK               |
# |  Cumulative Breaks   | 104 <= 120 |               OK               |
# |    Duty Duration     | 441 <= 445 |               OK               |
# | Max Continuous Drive | 145 <= 180 |               OK               |
# |  Jurisdiction Match  |   2 == 2   |               OK               |
# |     Rake Changes     |     2      | PVGW after 523, KKDA after 929 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #5 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   260   | VND  | PVGW | 17:30 | 18:29 |      59      |     0      |     -      |               -                |
# |   513   | PVGW | PVGW | 18:29 | 19:05 |      36      |     0      |     -      |               -                |
# |   298   | PVGW | KKDA | 19:05 | 20:10 |      65      |     31     | 31 mins OK | Rake changed at KKDA after 298 |
# |   888   | KKDA | MUPR | 20:41 | 20:57 |      16      |     3      |     -      |               -                |
# |   894   | MUPR | KKDA | 21:00 | 21:15 |      15      |     0      |     -      |               -                |
# |   345   | KKDA | PVGW | 21:15 | 22:21 |      66      |     53     | 53 mins OK | Rake changed at PVGW after 345 |
# |   371   | PVGW | KKDA | 23:14 | 24:20 |      66      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 326 <= 360 |               OK               |
# |  Cumulative Breaks   | 84 <= 120  |               OK               |
# |    Duty Duration     | 410 <= 445 |               OK               |
# | Max Continuous Drive | 95 <= 180  |               OK               |
# |  Jurisdiction Match  |   2 == 2   |               OK               |
# |     Rake Changes     |     2      | KKDA after 298, PVGW after 345 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #6 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   502   | PVGW | PVGW | 17:29 | 18:03 |      34      |     30     | 30 mins OK | Rake changed at PVGW after 502 |
# |   514   | PVGW | PVGW | 18:33 | 19:10 |      37      |     0      |     -      |               -                |
# |   299   | PVGW | KKDA | 19:10 | 20:16 |      66      |     0      |     -      |               -                |
# |   879   | KKDA | MUPR | 20:16 | 20:31 |      15      |     2      |     -      |               -                |
# |   886   | MUPR | KKDA | 20:33 | 20:49 |      16      |     34     | 34 mins OK | Rake changed at KKDA after 886 |
# |   903   | KKDA | MUPR | 21:23 | 21:38 |      15      |     2      |     -      |               -                |
# |   909   | MUPR | KKDA | 21:40 | 21:55 |      15      |     0      |     -      |               -                |
# |   357   | KKDA | PVGW | 21:55 | 23:01 |      66      |     50     | 50 mins OK | Rake changed at PVGW after 357 |
# |   562   | PVGW | MKPR | 23:51 | 24:26 |      35      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+------------------------------------------------+
# |      Constraint      | Condition  |                     Status                     |
# +----------------------+------------+------------------------------------------------+
# |  Total Driving Time  | 303 <= 360 |                       OK                       |
# |  Cumulative Breaks   | 114 <= 120 |                       OK                       |
# |    Duty Duration     | 417 <= 445 |                       OK                       |
# | Max Continuous Drive | 120 <= 180 |                       OK                       |
# |  Jurisdiction Match  |   1 == 1   |                       OK                       |
# |     Rake Changes     |     3      | PVGW after 502, KKDA after 886, PVGW after 357 |
# +----------------------+------------+------------------------------------------------+
#
# =================  Duty #7 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   501   | MKPD | PVGW | 17:27 | 17:42 |      15      |     38     | 38 mins OK | Rake changed at PVGW after 501 |
# |   511   | PVGW | PVGW | 18:20 | 18:54 |      34      |     0      |     -      |               -                |
# |   293   | PVGW | KKDA | 18:54 | 20:00 |      66      |     0      |     -      |               -                |
# |   873   | KKDA | MUPR | 20:00 | 20:15 |      15      |     3      |     -      |               -                |
# |   880   | MUPR | KKDA | 20:18 | 20:33 |      15      |     62     | 62 mins OK | Rake changed at KKDA after 880 |
# |   907   | KKDA | MUPR | 21:35 | 21:50 |      15      |     5      |     -      |               -                |
# |   913   | MUPR | KKDA | 21:55 | 22:10 |      15      |     0      |     -      |               -                |
# |   360   | KKDA | PVGW | 22:10 | 23:16 |      66      |     0      |     -      |               -                |
# |   559   | PVGW | DDSC | 23:16 | 24:27 |      71      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 320 <= 360 |               OK               |
# |  Cumulative Breaks   | 100 <= 120 |               OK               |
# |    Duty Duration     | 420 <= 445 |               OK               |
# | Max Continuous Drive | 172 <= 180 |               OK               |
# |  Jurisdiction Match  |   1 == 1   |               OK               |
# |     Rake Changes     |     2      | PVGW after 501, KKDA after 880 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #8 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   257   | PVGW | KKDA | 17:21 | 18:27 |      66      |     0      |     -      |               -                |
# |   837   | KKDA | MUPR | 18:27 | 18:42 |      15      |     3      |     -      |               -                |
# |   844   | MUPR | KKDA | 18:45 | 19:00 |      15      |     0      |     -      |               -                |
# |   296   | KKDA | PVGW | 19:00 | 20:07 |      67      |     30     | 30 mins OK | Rake changed at PVGW after 296 |
# |   332   | PVGW | KKDA | 20:37 | 21:42 |      65      |     0      |     -      |               -                |
# |   910   | KKDA | MUPR | 21:42 | 21:58 |      16      |     2      |     -      |               -                |
# |   915   | MUPR | KKDA | 22:00 | 22:15 |      15      |     0      |     -      |               -                |
# |   362   | KKDA | PVGW | 22:15 | 23:21 |      66      |     53     | 53 mins OK | Rake changed at PVGW after 362 |
# |   563   | PVGW | MKPD | 24:14 | 24:29 |      15      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 345 <= 360 |               OK               |
# |  Cumulative Breaks   | 83 <= 120  |               OK               |
# |    Duty Duration     | 428 <= 445 |               OK               |
# | Max Continuous Drive | 99 <= 180  |               OK               |
# |  Jurisdiction Match  |   1 == 1   |               OK               |
# |     Rake Changes     |     2      | PVGW after 296, PVGW after 362 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #9 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   499   | PVGW | PVGW | 17:17 | 17:52 |      35      |     60     | 60 mins OK | Rake changed at PVGW after 499 |
# |   517   | PVGW | PVGW | 18:52 | 19:25 |      33      |     0      |     -      |               -                |
# |   305   | PVGW | KKDA | 19:25 | 20:31 |      66      |     36     | 36 mins OK | Rake changed at KKDA after 305 |
# |   897   | KKDA | MUPR | 21:07 | 21:22 |      15      |     3      |     -      |               -                |
# |   904   | MUPR | KKDA | 21:25 | 21:40 |      15      |     0      |     -      |               -                |
# |   352   | KKDA | PVGW | 21:40 | 22:47 |      67      |     0      |     -      |               -                |
# |   556   | PVGW | MKPD | 22:47 | 23:02 |      15      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 249 <= 360 |               OK               |
# |  Cumulative Breaks   | 96 <= 120  |               OK               |
# |    Duty Duration     | 345 <= 445 |               OK               |
# | Max Continuous Drive | 115 <= 180 |               OK               |
# |  Jurisdiction Match  |   1 == 1   |               OK               |
# |     Rake Changes     |     2      | PVGW after 499, KKDA after 305 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #10 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   254   | KKDA | PVGW | 17:14 | 18:20 |      66      |     65     | 65 mins OK | Rake changed at PVGW after 254 |
# |   524   | PVGW | PVGW | 19:25 | 20:01 |      36      |     0      |     -      |               -                |
# |   319   | PVGW | KKDA | 20:01 | 21:07 |      66      |     38     | 38 mins OK | Rake changed at KKDA after 319 |
# |   354   | KKDA | PVGW | 21:45 | 22:51 |      66      |     0      |     -      |               -                |
# |   557   | PVGW | MVPO | 22:51 | 24:33 |     102      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 336 <= 360 |               OK               |
# |  Cumulative Breaks   | 103 <= 120 |               OK               |
# |    Duty Duration     | 439 <= 445 |               OK               |
# | Max Continuous Drive | 168 <= 180 |               OK               |
# |  Jurisdiction Match  |   2 == 2   |               OK               |
# |     Rake Changes     |     2      | PVGW after 254, KKDA after 319 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #11 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   252   | KKDA | PVGW | 17:07 | 18:14 |      67      |     0      |     -      |               -                |
# |   510   | PVGW | PVGW | 18:14 | 18:49 |      35      |     0      |     -      |               -                |
# |   291   | PVGW | KKDA | 18:49 | 19:55 |      66      |     54     | 54 mins OK | Rake changed at KKDA after 291 |
# |   337   | KKDA | PVGW | 20:49 | 21:55 |      66      |     34     | 34 mins OK | Rake changed at PVGW after 337 |
# |   364   | PVGW | KKDA | 22:29 | 23:35 |      66      |     0      |     -      |               -                |
# |   934   | KKDA | MUPR | 23:35 | 23:51 |      16      |     0      |     -      |               -                |
# |   938   | MUPR | SVVR | 23:51 | 23:57 |      6       |     5      |     -      |               -                |
# |   375   | SVVR | VND  | 24:02 | 24:32 |      30      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 357 <= 360 |               OK               |
# |  Cumulative Breaks   | 88 <= 120  |               OK               |
# |    Duty Duration     | 445 <= 445 |               OK               |
# | Max Continuous Drive | 123 <= 180 |               OK               |
# |  Jurisdiction Match  |   2 == 2   |               OK               |
# |     Rake Changes     |     2      | KKDA after 291, PVGW after 337 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #12 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   251   | PVGW | KKDA | 17:06 | 18:12 |      66      |     0      |     -      |               -                |
# |   831   | KKDA | MUPR | 18:12 | 18:27 |      15      |     2      |     -      |               -                |
# |   838   | MUPR | KKDA | 18:29 | 18:45 |      16      |     0      |     -      |               -                |
# |   290   | KKDA | PVGW | 18:45 | 19:51 |      66      |     31     | 31 mins OK | Rake changed at PVGW after 290 |
# |   327   | PVGW | KKDA | 20:22 | 21:27 |      65      |     0      |     -      |               -                |
# |   905   | KKDA | MUPR | 21:27 | 21:43 |      16      |     2      |     -      |               -                |
# |   911   | MUPR | KKDA | 21:45 | 22:01 |      16      |     52     | 52 mins OK | Rake changed at KKDA after 911 |
# |    4    | KKDA | IPE  | 22:53 | 23:00 |      7       |     0      |     -      |               -                |
# |    5    | IPE  | PVGW | 23:00 | 23:59 |      59      |     0      |     -      |               -                |
# |    8    | PVGW | MKPR | 23:59 | 24:13 |      14      |     0      |     -      |               -                |
# |    9    | MKPR | MKPD | 24:13 | 24:14 |      1       |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 345 <= 360 |               OK               |
# |  Cumulative Breaks   | 83 <= 120  |               OK               |
# |    Duty Duration     | 428 <= 445 |               OK               |
# | Max Continuous Drive | 99 <= 180  |               OK               |
# |  Jurisdiction Match  |   1 == 1   |               OK               |
# |     Rake Changes     |     2      | PVGW after 290, KKDA after 911 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #13 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   248   | VND  | PVGW | 16:59 | 17:58 |      59      |     0      |     -      |               -                |
# |   507   | PVGW | PVGW | 17:58 | 18:34 |      36      |     0      |     -      |               -                |
# |   285   | PVGW | KKDA | 18:34 | 19:39 |      65      |     54     | 54 mins OK | Rake changed at KKDA after 285 |
# |   331   | KKDA | PVGW | 20:33 | 21:40 |      67      |     34     | 34 mins OK | Rake changed at PVGW after 331 |
# |   361   | PVGW | KKDA | 22:14 | 23:20 |      66      |     0      |     -      |               -                |
# |   932   | KKDA | MUPR | 23:20 | 23:36 |      16      |     0      |     -      |               -                |
# |   935   | MUPR | SVVR | 23:36 | 23:42 |      6       |     5      |     -      |               -                |
# |   374   | SVVR | VND  | 23:47 | 24:17 |      30      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 350 <= 360 |               OK               |
# |  Cumulative Breaks   | 88 <= 120  |               OK               |
# |    Duty Duration     | 438 <= 445 |               OK               |
# | Max Continuous Drive | 123 <= 180 |               OK               |
# |  Jurisdiction Match  |   2 == 2   |               OK               |
# |     Rake Changes     |     2      | KKDA after 285, PVGW after 331 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #14 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   495   | MKPD | PVGW | 16:56 | 17:11 |      15      |     0      |     -      |               -                |
# |   253   | PVGW | KKDA | 17:11 | 18:17 |      66      |     0      |     -      |               -                |
# |   833   | KKDA | MUPR | 18:17 | 18:32 |      15      |     3      |     -      |               -                |
# |   840   | MUPR | KKDA | 18:35 | 18:50 |      15      |     0      |     -      |               -                |
# |   292   | KKDA | PVGW | 18:50 | 19:56 |      66      |     31     | 31 mins OK | Rake changed at PVGW after 292 |
# |   536   | PVGW | PVGW | 20:27 | 21:07 |      40      |     0      |     -      |               -                |
# |   343   | PVGW | KKDA | 21:07 | 22:12 |      65      |     56     | 56 mins OK | Rake changed at KKDA after 343 |
# |   370   | KKDA | PVGW | 23:08 | 24:14 |      66      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 351 <= 360 |               OK               |
# |  Cumulative Breaks   | 87 <= 120  |               OK               |
# |    Duty Duration     | 438 <= 445 |               OK               |
# | Max Continuous Drive | 114 <= 180 |               OK               |
# |  Jurisdiction Match  |   1 == 1   |               OK               |
# |     Rake Changes     |     2      | PVGW after 292, KKDA after 343 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #15 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   804   | KKDA | MUPR | 16:53 | 17:08 |      15      |     3      |     -      |               -                |
# |   809   | MUPR | KKDA | 17:11 | 17:26 |      15      |     0      |     -      |               -                |
# |   258   | KKDA | PVGW | 17:26 | 18:33 |      67      |     83     | 83 mins OK | Rake changed at PVGW after 258 |
# |   530   | PVGW | PVGW | 19:56 | 20:29 |      33      |     0      |     -      |               -                |
# |   330   | PVGW | KKDA | 20:29 | 21:35 |      66      |     37     | 37 mins OK | Rake changed at KKDA after 330 |
# |   918   | KKDA | MUPR | 22:12 | 22:28 |      16      |     0      |     -      |               -                |
# |   921   | MUPR | MUPR | 22:28 | 22:48 |      20      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 235 <= 360 |               OK               |
# |  Cumulative Breaks   | 120 <= 120 |               OK               |
# |    Duty Duration     | 355 <= 445 |               OK               |
# | Max Continuous Drive | 36 <= 180  |               OK               |
# |  Jurisdiction Match  |   2 == 2   |               OK               |
# |     Rake Changes     |     2      | PVGW after 258, KKDA after 330 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #16 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   494   | PVGW | PVGW | 16:51 | 17:26 |      35      |     0      |     -      |               -                |
# |   259   | PVGW | KKDA | 17:26 | 18:32 |      66      |     0      |     -      |               -                |
# |   839   | KKDA | MUPR | 18:32 | 18:47 |      15      |     3      |     -      |               -                |
# |   846   | MUPR | KKDA | 18:50 | 19:05 |      15      |     65     | 65 mins OK | Rake changed at KKDA after 846 |
# |   877   | KKDA | MUPR | 20:10 | 20:26 |      16      |     2      |     -      |               -                |
# |   884   | MUPR | KKDA | 20:28 | 20:44 |      16      |     0      |     -      |               -                |
# |   336   | KKDA | PVGW | 20:44 | 21:50 |      66      |     0      |     -      |               -                |
# |   548   | PVGW | PVGW | 21:50 | 22:29 |      39      |     32     | 32 mins OK | Rake changed at PVGW after 548 |
# |   558   | PVGW | DDSC | 23:01 | 24:12 |      71      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 344 <= 360 |               OK               |
# |  Cumulative Breaks   | 97 <= 120  |               OK               |
# |    Duty Duration     | 441 <= 445 |               OK               |
# | Max Continuous Drive | 119 <= 180 |               OK               |
# |  Jurisdiction Match  |   1 == 1   |               OK               |
# |     Rake Changes     |     2      | KKDA after 846, PVGW after 548 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #17 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   242   | KKDA | PVGW | 16:42 | 17:48 |      66      |     0      |     -      |               -                |
# |   505   | PVGW | PVGW | 17:48 | 18:23 |      35      |     0      |     -      |               -                |
# |   281   | PVGW | KKDA | 18:23 | 19:29 |      66      |     54     | 54 mins OK | Rake changed at KKDA after 281 |
# |   328   | KKDA | PVGW | 20:23 | 21:29 |      66      |     35     | 35 mins OK |               -                |
# |   359   | PVGW | KKDA | 22:04 | 23:10 |      66      |     0      |     -      |               -                |
# |   930   | KKDA | MUPR | 23:10 | 23:26 |      16      |     0      |     -      |               -                |
# |   568   | MUPR | MUPR | 23:26 | 23:45 |      19      |     0      |     -      |               -                |
# |   936   | MUPR | MUPR | 23:45 | 24:05 |      20      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+----------------+
# |      Constraint      | Condition  |     Status     |
# +----------------------+------------+----------------+
# |  Total Driving Time  | 354 <= 360 |       OK       |
# |  Cumulative Breaks   | 89 <= 120  |       OK       |
# |    Duty Duration     | 443 <= 445 |       OK       |
# | Max Continuous Drive | 121 <= 180 |       OK       |
# |  Jurisdiction Match  |   2 == 2   |       OK       |
# |     Rake Changes     |     1      | KKDA after 281 |
# +----------------------+------------+----------------+
#
# =================  Duty #18 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   241   | PVGW | KKDA | 16:40 | 17:46 |      66      |     0      |     -      |               -                |
# |   821   | KKDA | MUPR | 17:46 | 18:01 |      15      |     3      |     -      |               -                |
# |   828   | MUPR | KKDA | 18:04 | 18:19 |      15      |     0      |     -      |               -                |
# |   280   | KKDA | PVGW | 18:19 | 19:25 |      66      |     42     | 42 mins OK | Rake changed at PVGW after 280 |
# |   321   | PVGW | KKDA | 20:07 | 21:12 |      65      |     0      |     -      |               -                |
# |   899   | KKDA | MUPR | 21:12 | 21:28 |      16      |     2      |     -      |               -                |
# |   906   | MUPR | KKDA | 21:30 | 21:45 |      15      |     53     | 53 mins OK | Rake changed at KKDA after 906 |
# |    0    | KKDA | IPE  | 22:38 | 22:45 |      7       |     0      |     -      |               -                |
# |    2    | IPE  | PVGW | 22:45 | 23:44 |      59      |     0      |     -      |               -                |
# |    6    | PVGW | MKPR | 23:44 | 23:58 |      14      |     0      |     -      |               -                |
# |    7    | MKPR | MKPD | 23:58 | 23:59 |      1       |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 344 <= 360 |               OK               |
# |  Cumulative Breaks   | 95 <= 120  |               OK               |
# |    Duty Duration     | 439 <= 445 |               OK               |
# | Max Continuous Drive | 99 <= 180  |               OK               |
# |  Jurisdiction Match  |   1 == 1   |               OK               |
# |     Rake Changes     |     2      | PVGW after 280, KKDA after 906 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #19 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   798   | KKDA | MUPR | 16:34 | 16:49 |      15      |     3      |     -      |               -                |
# |   803   | MUPR | KKDA | 16:52 | 17:07 |      15      |     75     | 75 mins OK | Rake changed at KKDA after 803 |
# |   835   | KKDA | MUPR | 18:22 | 18:37 |      15      |     3      |     -      |               -                |
# |   842   | MUPR | KKDA | 18:40 | 18:55 |      15      |     0      |     -      |               -                |
# |   294   | KKDA | PVGW | 18:55 | 20:01 |      66      |     0      |     -      |               -                |
# |   531   | PVGW | PVGW | 20:01 | 20:37 |      36      |     42     | 42 mins OK | Rake changed at PVGW after 531 |
# |   543   | PVGW | PVGW | 21:19 | 21:54 |      35      |     0      |     -      |               -                |
# |   356   | PVGW | KKDA | 21:54 | 23:00 |      66      |     0      |     -      |               -                |
# |   928   | KKDA | MUPR | 23:00 | 23:16 |      16      |     0      |     -      |               -                |
# |   931   | MUPR | SVVR | 23:16 | 23:22 |      6       |     5      |     -      |               -                |
# |   373   | SVVR | VND  | 23:27 | 23:57 |      30      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 326 <= 360 |               OK               |
# |  Cumulative Breaks   | 117 <= 120 |               OK               |
# |    Duty Duration     | 443 <= 445 |               OK               |
# | Max Continuous Drive | 158 <= 180 |               OK               |
# |  Jurisdiction Match  |   2 == 2   |               OK               |
# |     Rake Changes     |     2      | KKDA after 803, PVGW after 531 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #20 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   491   | PVGW | PVGW | 16:32 | 17:06 |      34      |     30     | 30 mins OK | Rake changed at PVGW after 491 |
# |   503   | PVGW | PVGW | 17:36 | 18:13 |      37      |     52     | 52 mins OK | Rake changed at PVGW after 503 |
# |   520   | PVGW | PVGW | 19:05 | 19:41 |      36      |     0      |     -      |               -                |
# |   311   | PVGW | KKDA | 19:41 | 20:47 |      66      |     0      |     -      |               -                |
# |   890   | KKDA | MUPR | 20:47 | 21:02 |      15      |     2      |     -      |               -                |
# |   896   | MUPR | KKDA | 21:04 | 21:20 |      16      |     30     | 30 mins OK | Rake changed at KKDA after 896 |
# |   912   | KKDA | MUPR | 21:50 | 22:05 |      15      |     5      |     -      |               -                |
# |   917   | MUPR | KKDA | 22:10 | 22:25 |      15      |     0      |     -      |               -                |
# |   363   | KKDA | PVGW | 22:25 | 23:31 |      66      |     0      |     -      |               -                |
# |   561   | PVGW | MKPD | 23:31 | 23:46 |      15      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+------------------------------------------------+
# |      Constraint      | Condition  |                     Status                     |
# +----------------------+------------+------------------------------------------------+
# |  Total Driving Time  | 322 <= 360 |                       OK                       |
# |  Cumulative Breaks   | 112 <= 120 |                       OK                       |
# |    Duty Duration     | 434 <= 445 |                       OK                       |
# | Max Continuous Drive | 119 <= 180 |                       OK                       |
# |  Jurisdiction Match  |   1 == 1   |                       OK                       |
# |     Rake Changes     |     3      | PVGW after 491, PVGW after 503, KKDA after 896 |
# +----------------------+------------+------------------------------------------------+
#
# =================  Duty #21 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   490   | MKPD | PVGW | 16:31 | 16:45 |      14      |     0      |     -      |               -                |
# |   243   | PVGW | KKDA | 16:45 | 17:51 |      66      |     57     | 57 mins OK | Rake changed at KKDA after 243 |
# |   845   | KKDA | MUPR | 18:48 | 19:03 |      15      |     3      |     -      |               -                |
# |   852   | MUPR | KKDA | 19:06 | 19:21 |      15      |     0      |     -      |               -                |
# |   304   | KKDA | PVGW | 19:21 | 20:27 |      66      |     32     | 32 mins OK | Rake changed at PVGW after 304 |
# |   340   | PVGW | KKDA | 20:59 | 22:05 |      66      |     0      |     -      |               -                |
# |   916   | KKDA | MUPR | 22:05 | 22:20 |      15      |     10     |     -      |               -                |
# |   923   | MUPR | KKDA | 22:30 | 22:45 |      15      |     0      |     -      |               -                |
# |   367   | KKDA | PVGW | 22:45 | 23:51 |      66      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# ...
# +---------+------+------+-------+-------+--------------+------------+------------+-------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+---------------+
# |      Constraint      | Condition  |    Status     |
# +----------------------+------------+---------------+
# |  Total Driving Time  | 331 <= 360 |      OK       |
# |  Cumulative Breaks   | 54 <= 120  |      OK       |
# |    Duty Duration     | 385 <= 445 |      OK       |
# | Max Continuous Drive | 180 <= 180 |      OK       |
# |  Jurisdiction Match  |   1 == 1   |      OK       |
# |     Rake Changes     |     1      | PVGW after 36 |
# +----------------------+------------+---------------+
#
# =================  Duty #104 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+-------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change          |
# +---------+------+------+-------+-------+--------------+------------+------------+-------------------------------+
# |   578   | SVVR | MUPR | 06:00 | 06:10 |      10      |     0      |     -      |               -               |
# |   581   | MUPR | KKDA | 06:10 | 06:25 |      15      |     0      |     -      |               -               |
# |   21    | KKDA | PVGW | 06:25 | 07:31 |      66      |     37     | 37 mins OK |               -               |
# |   52    | PVGW | KKDA | 08:08 | 09:14 |      66      |     60     | 60 mins OK | Rake changed at KKDA after 52 |
# |   108   | KKDA | PVGW | 10:14 | 11:20 |      66      |     0      |     -      |               -               |
# |   436   | PVGW | PVGW | 11:20 | 11:53 |      33      |     0      |     -      |               -               |
# |   147   | PVGW | KKDA | 11:53 | 12:59 |      66      |     0      |     -      |               -               |
# |   729   | KKDA | MUPR | 12:59 | 13:14 |      15      |     -      |     -      |               -               |
# +---------+------+------+-------+-------+--------------+------------+------------+-------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+---------------+
# |      Constraint      | Condition  |    Status     |
# +----------------------+------------+---------------+
# |  Total Driving Time  | 337 <= 360 |      OK       |
# |  Cumulative Breaks   | 97 <= 120  |      OK       |
# |    Duty Duration     | 434 <= 445 |      OK       |
# | Max Continuous Drive | 180 <= 180 |      OK       |
# |  Jurisdiction Match  |   2 == 2   |      OK       |
# |     Rake Changes     |     1      | KKDA after 52 |
# +----------------------+------------+---------------+
#
# =================  Duty #105 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   579   | MUPR | KKDA | 06:00 | 06:16 |      16      |     59     | 59 mins OK | Rake changed at KKDA after 579 |
# |   33    | KKDA | PVGW | 07:15 | 08:21 |      66      |     48     | 48 mins OK | Rake changed at PVGW after 33  |
# |   409   | PVGW | PVGW | 09:09 | 09:46 |      37      |     0      |     -      |               -                |
# |   96    | PVGW | KKDA | 09:46 | 10:52 |      66      |     0      |     -      |               -                |
# |   680   | KKDA | MUPR | 10:52 | 11:07 |      15      |     3      |     -      |               -                |
# |   689   | MUPR | KKDA | 11:10 | 11:25 |      15      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+-------------------------------+
# |      Constraint      | Condition  |            Status             |
# +----------------------+------------+-------------------------------+
# |  Total Driving Time  | 218 <= 360 |              OK               |
# |  Cumulative Breaks   | 107 <= 120 |              OK               |
# |    Duty Duration     | 325 <= 445 |              OK               |
# | Max Continuous Drive | 136 <= 180 |              OK               |
# |  Jurisdiction Match  |   2 == 2   |              OK               |
# |     Rake Changes     |     2      | KKDA after 579, PVGW after 33 |
# +----------------------+------------+-------------------------------+
#
# =================  Duty #106 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   571   | MKPR | PVGW | 05:50 | 06:03 |      13      |     51     | 51 mins OK | Rake changed at PVGW after 571 |
# |   27    | PVGW | KKDA | 06:54 | 08:00 |      66      |     0      |     -      |               -                |
# |   611   | KKDA | MUPR | 08:00 | 08:15 |      15      |     3      |     -      |               -                |
# |   618   | MUPR | KKDA | 08:18 | 08:34 |      16      |     33     | 33 mins OK | Rake changed at KKDA after 618 |
# |   637   | KKDA | MUPR | 09:07 | 09:22 |      15      |     3      |     -      |               -                |
# |   643   | MUPR | KKDA | 09:25 | 09:41 |      16      |     0      |     -      |               -                |
# |   94    | KKDA | PVGW | 09:41 | 10:47 |      66      |     0      |     -      |               -                |
# |   430   | PVGW | PVGW | 10:47 | 11:21 |      34      |     33     | 33 mins OK | Rake changed at PVGW after 430 |
# |   443   | PVGW | MKPD | 11:54 | 12:09 |      15      |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+------------------------------------------------+
# |      Constraint      | Condition  |                     Status                     |
# +----------------------+------------+------------------------------------------------+
# |  Total Driving Time  | 262 <= 360 |                       OK                       |
# |  Cumulative Breaks   | 117 <= 120 |                       OK                       |
# |    Duty Duration     | 379 <= 445 |                       OK                       |
# | Max Continuous Drive | 100 <= 180 |                       OK                       |
# |  Jurisdiction Match  |   1 == 1   |                       OK                       |
# |     Rake Changes     |     3      | PVGW after 571, KKDA after 618, PVGW after 430 |
# +----------------------+------------+------------------------------------------------+
#
# =================  Duty #107 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   10    | MVPO | KKDA | 05:45 | 06:42 |      57      |     0      |     -      |               -                |
# |   587   | KKDA | MUPR | 06:42 | 06:57 |      15      |     3      |     -      |               -                |
# |   591   | MUPR | KKDA | 07:00 | 07:15 |      15      |     32     | 32 mins OK | Rake changed at KKDA after 591 |
# |   44    | KKDA | PVGW | 07:47 | 08:53 |      66      |     0      |     -      |               -                |
# |   404   | PVGW | PVGW | 08:53 | 09:29 |      36      |     59     | 59 mins OK | Rake changed at PVGW after 404 |
# |   113   | PVGW | KKDA | 10:28 | 11:34 |      66      |     0      |     -      |               -                |
# |   699   | KKDA | MUPR | 11:34 | 11:49 |      15      |     4      |     -      |               -                |
# |   706   | MUPR | KKDA | 11:53 | 12:09 |      16      |     0      |     -      |               -                |
# |   153   | KKDA | VND  | 12:09 | 12:15 |      6       |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 299 <= 360 |               OK               |
# |  Cumulative Breaks   | 91 <= 120  |               OK               |
# |    Duty Duration     | 390 <= 445 |               OK               |
# | Max Continuous Drive | 107 <= 180 |               OK               |
# |  Jurisdiction Match  |   2 == 2   |               OK               |
# |     Rake Changes     |     2      | KKDA after 591, PVGW after 404 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #108 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   570   | IPE  | PVGW | 05:45 | 06:57 |      72      |     0      |     -      |               -                |
# |   384   | PVGW | PVGW | 06:57 | 07:30 |      33      |     31     | 31 mins OK | Rake changed at PVGW after 384 |
# |   393   | PVGW | PVGW | 08:01 | 08:35 |      34      |     0      |     -      |               -                |
# |   66    | PVGW | KKDA | 08:35 | 09:41 |      66      |     0      |     -      |               -                |
# |   649   | KKDA | MUPR | 09:41 | 09:56 |      15      |     2      |     -      |               -                |
# |   656   | MUPR | KKDA | 09:58 | 10:14 |      16      |     50     | 50 mins OK | Rake changed at KKDA after 656 |
# |   686   | KKDA | MUPR | 11:04 | 11:19 |      15      |     4      |     -      |               -                |
# |   694   | MUPR | KKDA | 11:23 | 11:39 |      16      |     0      |     -      |               -                |
# |   142   | KKDA | VND  | 11:39 | 11:45 |      6       |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+--------------------------------+
# |      Constraint      | Condition  |             Status             |
# +----------------------+------------+--------------------------------+
# |  Total Driving Time  | 279 <= 360 |               OK               |
# |  Cumulative Breaks   | 81 <= 120  |               OK               |
# |    Duty Duration     | 360 <= 445 |               OK               |
# | Max Continuous Drive | 117 <= 180 |               OK               |
# |  Jurisdiction Match  |   2 == 2   |               OK               |
# |     Rake Changes     |     2      | PVGW after 384, KKDA after 656 |
# +----------------------+------------+--------------------------------+
#
# =================  Duty #109 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+-------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change          |
# +---------+------+------+-------+-------+--------------+------------+------------+-------------------------------+
# |   11    | SAKP | KKDA | 05:45 | 06:59 |      74      |     0      |     -      |               -               |
# |   590   | KKDA | MUPR | 06:59 | 07:14 |      15      |     4      |     -      |               -               |
# |   595   | MUPR | KKDA | 07:18 | 07:33 |      15      |     0      |     -      |               -               |
# |   39    | KKDA | PVGW | 07:33 | 08:39 |      66      |     63     | 63 mins OK | Rake changed at PVGW after 39 |
# |   95    | PVGW | KKDA | 09:42 | 10:48 |      66      |     0      |     -      |               -               |
# |   678   | KKDA | MUPR | 10:48 | 11:03 |      15      |     2      |     -      |               -               |
# |   687   | MUPR | KKDA | 11:05 | 11:21 |      16      |     0      |     -      |               -               |
# |   135   | KKDA | PVGW | 11:21 | 12:27 |      66      |     -      |     -      |               -               |
# +---------+------+------+-------+-------+--------------+------------+------------+-------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+---------------+
# |      Constraint      | Condition  |    Status     |
# +----------------------+------------+---------------+
# |  Total Driving Time  | 339 <= 360 |      OK       |
# |  Cumulative Breaks   | 63 <= 120  |      OK       |
# |    Duty Duration     | 402 <= 445 |      OK       |
# | Max Continuous Drive | 165 <= 180 |      OK       |
# |  Jurisdiction Match  |   1 == 1   |      OK       |
# |     Rake Changes     |     1      | PVGW after 39 |
# +----------------------+------------+---------------+
#
# =================  Duty #110 =================
#
# ---  Duty Timeline ---
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# | Service | From |  To  | Start |  End  | Service Time | Gap (mins) |   Break    |          Rake Change           |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
# |   577   | MUPR | MUPR | 05:30 | 06:20 |      50      |     0      |     -      |               -                |
# |   582   | MUPR | KKDA | 06:20 | 06:35 |      15      |     59     | 59 mins OK | Rake changed at KKDA after 582 |
# |   601   | KKDA | MUPR | 07:34 | 07:49 |      15      |     3      |     -      |               -                |
# |   608   | MUPR | KKDA | 07:52 | 08:08 |      16      |     0      |     -      |               -                |
# |   53    | KKDA | PVGW | 08:08 | 09:14 |      66      |     36     | 36 mins OK |               -                |
# |   98    | PVGW | KKDA | 09:50 | 10:56 |      66      |     0      |     -      |               -                |
# |   682   | KKDA | MUPR | 10:56 | 11:11 |      15      |     3      |     -      |               -                |
# |   691   | MUPR | KKDA | 11:14 | 11:29 |      15      |     0      |     -      |               -                |
# |   139   | KKDA | VND  | 11:29 | 11:36 |      7       |     -      |     -      |               -                |
# +---------+------+------+-------+-------+--------------+------------+------------+--------------------------------+
#
# ---  Constraint Summary ---
# +----------------------+------------+----------------+
# |      Constraint      | Condition  |     Status     |
# +----------------------+------------+----------------+
# |  Total Driving Time  | 271 <= 360 |       OK       |
# |  Cumulative Breaks   | 95 <= 120  |       OK       |
# |    Duty Duration     | 366 <= 445 |       OK       |
# | Max Continuous Drive | 106 <= 180 |       OK       |
# |  Jurisdiction Match  |   2 == 2   |       OK       |
# |     Rake Changes     |     1      | KKDA after 582 |
# +----------------------+------------+----------------+
